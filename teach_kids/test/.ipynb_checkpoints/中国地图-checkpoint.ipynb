# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap

# %%
# 画一张最简单的地图，默认的投影方式是 cyl

m = Basemap()
m.drawcoastlines()
plt.show()

# %%
# 使用 ortho 正射投影

m = Basemap(projection='ortho', lat_0=0, lon_0=105)
m.drawcoastlines()
plt.show()

# %%
# 可以添加颜色

map = Basemap(projection='ortho', lat_0=0, lon_0=105)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral', lake_color='aqua')
map.drawcoastlines()
#map.drawcountries()
plt.show()

# %%
# 添加政治边界

map = Basemap(projection='ortho', lat_0=0, lon_0=105)
map.drawmapboundary(fill_color='aqua')
map.fillcontinents(color='coral', lake_color='aqua')
map.drawcoastlines()
map.drawcountries()
plt.show()

# %%
# 绘制一张 NASA 蓝色大理石图像作为地图背景

map = Basemap(projection='ortho', lat_0=0, lon_0=105)
#map.drawcoastlines()
#map.drawcountries()
map.bluemarble()
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
# 在平面上画出政治边界

plt.figure(figsize=(16,8))
m = Basemap()
m.drawcoastlines()
#m.drawcountries(linewidth=1.5)
m.drawcountries()
plt.show()

# %%
# 把目光放在中国，但是默认的投影cyl是圆柱等距离投影，高纬度地区被横向拉长了

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=72, llcrnrlat=3, urcrnrlon=136, urcrnrlat=54)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)

plt.show()

# %%
# 墨卡托投影好像也不对

plt.figure(figsize=(16,8))
#m = Basemap(llcrnrlon=72, llcrnrlat=3, urcrnrlon=136, urcrnrlat=54)
m = Basemap(resolution='l', projection='merc', llcrnrlon=72.0, llcrnrlat=3.0, urcrnrlon=136.0, urcrnrlat=54.0)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)

plt.show()

# %%
# 采用lcc兰勃特投影

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)

plt.show()

# %%
plt.figure(figsize=(16,8))

m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

plt.show()

# %%
plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

from matplotlib.patches import Polygon

ax = plt.gca()
for nshape, seg in enumerate(m.states):
    poly = Polygon(seg, facecolor='#E60000')
    ax.add_patch(poly)

# %%
# 台湾是中华人民共和国不可分割的领土

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

from matplotlib.patches import Polygon

# 函数 gca() 是 Get Current Axes 的缩写，实际上就是要获得当前图形的坐标轴
ax = plt.gca()
for nshape, seg in enumerate(m.states):
    poly = Polygon(seg, facecolor='#E60000')
    ax.add_patch(poly)
    
m.readshapefile('gadm36_TWN_shp/gadm36_TWN_0', 'taiwan', drawbounds=True)

for nshape, seg in enumerate(m.taiwan):
    poly = Polygon(seg, facecolor='#E60000')
    ax.add_patch(poly)

# %%
for shapedict in m.states_info:
    statename = shapedict['NL_NAME_1']
    p = statename.split('|')
    if len(p) > 1:
        s = p[1]
    else:
        s = p[0]
    print(s)
for shapedict in m.taiwan_info:
    s = shapedict['NAME_CHINE']
    print(s)
# Out:
# 安徽
# 北京
# 重庆
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# 福建
# ...

# %%
for shapedict in m.states_info:
    print(shapedict)
    print(len(shapedict))
# Out:
# {'GID_0': 'CHN', 'NAME_0': 'China', 'GID_1': 'CHN.1_1', 'NAME_1': 'Anhui', 'VARNAME_1': 'Ānhuī', 'NL_NAME_1': '安徽|安徽', 'TYPE_1': 'Shěng', 'ENGTYPE_1': 'Province', 'CC_1': '', 'HASC_1': 'CN.AH', 'RINGNUM': 1, 'SHAPENUM': 1}
# 12
# {'GID_0': 'CHN', 'NAME_0': 'China', 'GID_1': 'CHN.2_1', 'NAME_1': 'Beijing', 'VARNAME_1': 'Běijīng', 'NL_NAME_1': '北京|北京', 'TYPE_1': 'Zhíxiáshì', 'ENGTYPE_1': 'Municipality', 'CC_1': '', 'HASC_1': 'CN.BJ', 'RINGNUM': 1, 'SHAPENUM': 2}
# 12
# {'GID_0': 'CHN', 'NAME_0': 'China', 'GID_1': 'CHN.3_1', 'NAME_1': 'Chongqing', 'VARNAME_1': 'Chóngqìng', 'NL_NAME_1': '重慶|重庆', 'TYPE_1': 'Zhíxiáshì', 'ENGTYPE_1': 'Municipality', 'CC_1': '', 'HASC_1': 'CN.CQ', 'RINGNUM': 1, 'SHAPENUM': 3}
# 12
# {'GID_0': 'CHN', 'NAME_0': 'China', 'GID_1': 'CHN.4_1', 'NAME_1': 'Fujian', 'VARNAME_1': 'Fújiàn', 'NL_NAME_1': '福建', 'TYPE_1': 'Shěng', 'ENGTYPE_1': 'Province', 'CC_1': '', 'HASC_1': 'CN.FJ', 'RINGNUM': 1, 'SHAPENUM': 4}
# 12
# ...

# %%
plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=115.2, llcrnrlat=39.2, urcrnrlon=117.8, urcrnrlat=41.2)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

plt.show()

# %% [markdown]
# ## 人口数据分析

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('data/2010年各地区户数人口数和性别比.csv')
df
# Out:
#      地区         合计       家庭户        集体户         人口数          男          女  \
# 0    全国  417722698  401934196  15788502  1332810869  682329104  650481765
# 1    北京    7355291    6680552    674739    19612368   10126430    9485938
# 2    天津    3963604    3661992    301612    12938693    6907091    6031602
# 3    河北   20813492   20395116    418376    71854210   36430286   35423924
# 4    山西   10654162   10330207    323955    35712101   18338760   17373341
# 5   内蒙古    8470472    8205498    264974    24706291   12838243   11868048
# 6    辽宁   15334912   14994046    340866    43746323   22147745   21598578
# 7    吉林    9162183    8998492    163691    27452815   13907218   13545597
# 8   黑龙江   13192935   13000088    192847    38313991   19426106   18887885
# 9    上海    8893483    8253257    640226    23019196   11854916   11164280
# 10   江苏   25635291   24381782   1253509    78660941   39626707   39034234
# 11   浙江   20060115   18854021   1206094    54426891   27965641   26461250
# ...

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.basemap import Basemap
from matplotlib.patches import Polygon
from matplotlib.colors import rgb2hex
import numpy as np
import pandas as pd

plt.figure(figsize=(16,8))
m = Basemap(llcrnrlon=77, llcrnrlat=14, urcrnrlon=140, urcrnrlat=51, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcountries(linewidth=1.5)
m.drawcoastlines()

# CHN_adm_shp/CHN_adm1 -> gadm36_CHN_shp/gadm36_CHN_1
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

df = pd.read_csv('data/2010年各地区户数人口数和性别比.csv')
df['省名'] = df.地区.str[:2]
df.set_index('省名', inplace=True)

statenames=[]
colors={}
cmap = plt.cm.YlOrRd
vmax = 100000000
vmin = 3000000
for shapedict in m.states_info:
    statename = shapedict['NL_NAME_1']
    p = statename.split('|')
    if len(p) > 1:
        s = p[1]
    else:
        s = p[0]
    s = s[:2]
    if s == '黑龍':
        s = '黑龙'
    statenames.append(s)
    pop = df['人口数'][s]
    colors[s] = cmap(np.sqrt((pop - vmin) / (vmax - vmin)))[:3]

ax = plt.gca()
for nshape, seg in enumerate(m.states):
    color = rgb2hex(colors[statenames[nshape]])
    poly = Polygon(seg, facecolor=color, edgecolor=color)
    ax.add_patch(poly)

plt.show()

# %% [markdown]
# ## 看看广东

# %%
plt.figure(figsize=(16,8))

m = Basemap(llcrnrlon=109, llcrnrlat=20, urcrnrlon=118, urcrnrlat=25, projection='lcc', lat_1=33, lat_2=45, lon_0=100)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_1', 'states', drawbounds=True)

plt.show()

# %%
plt.figure(figsize=(16,8))
m = Basemap(resolution='l', projection='merc', llcrnrlon=109, llcrnrlat=20, urcrnrlon=118, urcrnrlat=26)
m.drawcoastlines()
m.drawcountries(linewidth=1.5)
m.readshapefile('gadm36_CHN_shp/gadm36_CHN_2', 'states', drawbounds=True, linewidth=1.5)

plt.show()
